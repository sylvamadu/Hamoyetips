# %%
import pandas as pd
import numpy as np
# %matplotlib inline

import matplotlib.pyplot as plt

# %%
df=pd.read_csv("fuel_ferc1.csv")

df.head(34)
# Out:
#                  record_id  utility_id_ferc1  report_year  \
# 0    f1_fuel_1994_12_1_0_7                 1         1994
# 1   f1_fuel_1994_12_1_0_10                 1         1994
# 2    f1_fuel_1994_12_2_0_1                 2         1994
# 3    f1_fuel_1994_12_2_0_7                 2         1994
# 4   f1_fuel_1994_12_2_0_10                 2         1994
# 5   f1_fuel_1994_12_2_0_13                 2         1994
# 6    f1_fuel_1994_12_2_1_1                 2         1994
# 7   f1_fuel_1994_12_2_1_10                 2         1994
# 8   f1_fuel_1994_12_2_2_10                 2         1994
# 9    f1_fuel_1994_12_4_0_1                 4         1994
# 10   f1_fuel_1994_12_4_0_2                 4         1994
# 11   f1_fuel_1994_12_4_0_4                 4         1994
# 12   f1_fuel_1994_12_4_0_5                 4         1994
# 13   f1_fuel_1994_12_6_0_1                 6         1994
# 14   f1_fuel_1994_12_6_0_2                 6         1994
# ...

# %%
fuel = df[(df['fuel_unit'] == 'ton') & (df['plant_name_ferc1'] == 'barry')]

fuel
# Out:
#                   record_id  utility_id_ferc1  report_year plant_name_ferc1  \
# 3     f1_fuel_1994_12_2_0_7                 2         1994            barry
# 1383  f1_fuel_1995_12_2_0_7                 2         1995            barry
# 3341  f1_fuel_1996_12_2_0_7                 2         1996            barry
# 4451  f1_fuel_1997_12_2_0_7                 2         1997            barry
# 5319  f1_fuel_1998_12_2_0_9                 2         1998            barry
#
#      fuel_type_code_pudl fuel_unit  fuel_qty_burned  fuel_mmbtu_per_unit  \
# 3                   coal       ton        3739484.0               23.950
# 1383                coal       ton        3902868.0               24.152
# 3341                coal       ton        4374378.0               24.100
# 4451                coal       ton        4653536.0               24.038
# 5319                coal       ton        4211990.0               24.188
#
#       fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# ...

# %%
df['plant_name_ferc1'].unique()
# Out:
# array(['rockport', 'rockport total plant', 'gorgas', ...,
#        'conemaugh (3.83%)', 'allegany station 133', nan], dtype=object)

# %%
df['plant_name_ferc1'].count()
# Out:
# 13973

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13974 entries, 0 to 13973
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   record_id                     13974 non-null  object
#  1   utility_id_ferc1              13974 non-null  int64
#  2   report_year                   13974 non-null  int64
#  3   plant_name_ferc1              13973 non-null  object
#  4   fuel_type_code_pudl           13973 non-null  object
#  5   fuel_unit                     13863 non-null  object
#  6   fuel_qty_burned               13973 non-null  float64
#  7   fuel_mmbtu_per_unit           13973 non-null  float64
#  8   fuel_cost_per_unit_burned     13973 non-null  float64
#  9   fuel_cost_per_unit_delivered  13973 non-null  float64
#  10  fuel_cost_per_mmbtu           13973 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 1.2+ MB

# %%
df['fuel_unit'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13969    False
# 13970    False
# 13971    False
# 13972    False
# 13973     True
# Name: fuel_unit, Length: 13974, dtype: bool
